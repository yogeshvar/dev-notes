# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
dataset = pd.read_csv("Data.csv")
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=1/3)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_test)
print(y_pred)
# Out:
# [102896.10100525  64158.86276946  61391.91718119 110274.62257397
#   47557.18923984  56780.34120074  68770.43874991  37411.72208284
#  107507.6769857  114886.19855442]

# %%
plt.scatter(X_train, Y_train, color="red")
plt.plot(X_train, regression.predict(X_train), color="blue")
plt.title('Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(X_test, Y_test, color="red")
plt.plot(X_train, regression.predict(X_train), color="blue")
plt.title('Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
print(regression.predict([[12]]))
# Out:
# [137944.07845668]

# %%
print(regression.coef_[0])
print(regression.intercept_)
# Out:
# 9223.151960902076
# 27266.25492585056

# %%
years_of_experience = 12
salary =  regression.coef_[0] * years_of_experience + regression.intercept_
print(salary)
# Out:
# 137944.07845667546
